# %% [markdown]
# ***
#
# <br>
# Let us look at how we can implement text classification using PyTorch
# <br>
#
# The dataset is from the Tweet Sentiment Extraction challenge from Kaggle(https://www.kaggle.com/c/tweet-sentiment-extraction/overview)
# <br>
#
# We would implement text classification using a simple embedding bag of words using PyTorch on tweet data to classify tweets as "positive","negative" or "neutral"
#
#
# <br>
#
# ***

# %%
import os
import re
import shutil
import string


from collections import Counter


import pandas as pd
import numpy as np

import sklearn


from sklearn.model_selection import train_test_split
# Out:
# /tmp/ipykernel_137600/2856313650.py:10: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ****
# Let us define methods to pre-process the review data
# ****

# %%
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

def remove_url(text): 
    url_pattern  = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    return url_pattern.sub(r'', text)
 # converting return value from list to string



def clean_text(text ): 
    delete_dict = {sp_character: '' for sp_character in string.punctuation} 
    delete_dict[' '] = ' ' 
    table = str.maketrans(delete_dict)
    text1 = text.translate(table)
    #print('cleaned:'+text1)
    textArr= text1.split()
    text2 = ' '.join([w for w in textArr if ( not w.isdigit() and  ( not w.isdigit() and len(w)>2))]) 
    
    return text2.lower()

# %%
def get_sentiment(sentiment):
    if sentiment == 'positive':
        return 2
    elif sentiment == 'negative':
        return 1
    else:
        return 0

# %%
train_data= pd.read_csv("data/tweet-sentiment-extraction/train.csv")
train_data.dropna(axis = 0, how ='any',inplace=True) 
train_data['Num_words_text'] = train_data['text'].apply(lambda x:len(str(x).split())) 
mask = train_data['Num_words_text'] >2
train_data = train_data[mask]
print('-------Train data--------')
print(train_data['sentiment'].value_counts())
print(len(train_data))
print('-------------------------')
max_train_sentence_length  = train_data['Num_words_text'].max()


train_data['text'] = train_data['text'].apply(remove_emoji)
train_data['text'] = train_data['text'].apply(remove_url)
train_data['text'] = train_data['text'].apply(clean_text)

train_data['label'] = train_data['sentiment'].apply(get_sentiment)

test_data= pd.read_csv("data/tweet-sentiment-extraction/test.csv")
test_data.dropna(axis = 0, how ='any',inplace=True) 
test_data['Num_words_text'] = test_data['text'].apply(lambda x:len(str(x).split())) 

max_test_sentence_length  = test_data['Num_words_text'].max()

mask = test_data['Num_words_text'] >2
test_data = test_data[mask]

print('-------Test data--------')
print(test_data['sentiment'].value_counts())
print(len(test_data))
print('-------------------------')

test_data['text'] = test_data['text'].apply(remove_emoji)
test_data['text'] = test_data['text'].apply(remove_url)
test_data['text'] = test_data['text'].apply(clean_text)

test_data['label'] = test_data['sentiment'].apply(get_sentiment)

print('Train Max Sentence Length :'+str(max_train_sentence_length))
print('Test Max Sentence Length :'+str(max_test_sentence_length))
# Out:
# -------Train data--------
# sentiment
# neutral     10704
# positive     8375
# negative     7673
# Name: count, dtype: int64
# 26752
# -------------------------
# -------Test data--------
# sentiment
# neutral     1376
# positive    1075
# negative     983
# Name: count, dtype: int64
# 3434
# -------------------------
# Train Max Sentence Length :33
# Test Max Sentence Length :32

# %%
train_data.head(10)
# Out:
#         textID                                               text  \
# 0   cb774db0d1                          have responded were going
# 1   549e992a42              sooo sad will miss you here san diego
# 2   088c60f138                                      boss bullying
# 3   9642c003ef                         what interview leave alone
# 4   358bd9e861  sons why couldnt they put them the releases al...
# 5   28b57f3990  some shameless plugging for the best rangers f...
# 6   6e0c6d75b1  2am feedings for the baby are fun when all smi...
# 8   e050245fbd                                           both you
# 9   fc2cbefa9d  journey wow just became cooler hehe that possible
# 10  2339a9b08b  much love hopeful reckon the chances are minim...
#
#                                         selected_text sentiment  \
# 0                 I`d have responded, if I were going   neutral
# 1                                            Sooo SAD  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       Sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 8                                         Both of you   neutral
# 9                        Wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
#
#     Num_words_text  label
# 0                7      0
# 1               10      1
# 2                5      1
# 3                5      1
# 4               14      1
# 5               12      0
# 6               14      2
# 8                3      0
# 9               10      2
# 10              23      0

# %%
test_data.head(10)
# Out:
#         textID                                               text sentiment  \
# 0   f87dea47db                               last session the day   neutral
# 1   96d74cb729  shanghai also really exciting precisely skyscr...  positive
# 2   eee518ae67  recession hit veronique branquinho she has qui...  negative
# 4   33987a8ee5                                               like  positive
# 5   726e501993                          thats great weee visitors  positive
# 6   261932614e                      think everyone hates here lol  negative
# 7   afa11da83f  soooooo wish could but school and myspace comp...  negative
# 8   e64208b4ef       and within short time the last clue all them   neutral
# 9   37bcad24ca  what did you get day alright havent done anyth...   neutral
# 10  24c92644a4  bike was put holdshould have known that argh t...  negative
#
#     Num_words_text  label
# 0                6      0
# 1               15      2
# 2               13      1
# 4                5      2
# 5                4      2
# 6                8      1
# 7               13      1
# 8               12      0
# 9               18      0
# 10              12      1

# %% [markdown]
# ***
# Let us create our train,valid and test datasets
# ***

# %%
X_train, X_valid, Y_train, Y_valid= train_test_split(train_data['text'].tolist(),\
                                                      train_data['label'].tolist(),\
                                                      test_size=0.2,\
                                                      stratify = train_data['label'].tolist(),\
                                                      random_state=0)


print('Train data len:'+str(len(X_train)))
print('Class distribution'+str(Counter(Y_train)))


print('Valid data len:'+str(len(X_valid)))
print('Class distribution'+ str(Counter(Y_valid)))

print('Test data len:'+str(len(test_data['text'].tolist())))
print('Class distribution'+ str(Counter(test_data['label'].tolist())))


train_dat =list(zip(Y_train,X_train))
valid_dat =list(zip(Y_valid,X_valid))
test_dat=list(zip(test_data['label'].tolist(),test_data['text'].tolist()))
# Out:
# Train data len:21401
# Class distributionCounter({0: 8563, 2: 6700, 1: 6138})
# Valid data len:5351
# Class distributionCounter({0: 2141, 2: 1675, 1: 1535})
# Test data len:3434
# Class distributionCounter({0: 1376, 2: 1075, 1: 983})

# %%
import torch
from torch.utils.data import DataLoader
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ***
# Let us create our vocabulary on train data
# ***

# %%
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator

tokenizer = get_tokenizer('basic_english')
train_iter = train_dat
def yield_tokens(data_iter):
    for _, text in data_iter:
        yield tokenizer(text)

vocab = build_vocab_from_iterator(yield_tokens(train_iter), specials=["<unk>"])
vocab.set_default_index(vocab["<unk>"])

# %% [markdown]
# Let us define our text and label preprocessing pipleines

# %%
text_pipeline = lambda x: vocab(tokenizer(x))
label_pipeline = lambda x: int(x)

# %%
text_pipeline('here is the an example')
# Out:
# [62, 0, 1, 0, 12881]

# %%
label_pipeline('1')
# Out:
# 1

# %% [markdown]
# Let us define our batch collation function

# %%
def collate_batch(batch):
    label_list, text_list, offsets = [], [], [0]
    for (_label, _text) in batch:
         label_list.append(label_pipeline(_label))
         processed_text = torch.tensor(text_pipeline(_text), dtype=torch.int64)
         text_list.append(processed_text)
         offsets.append(processed_text.size(0))
    label_list = torch.tensor(label_list, dtype=torch.int64)
    offsets = torch.tensor(offsets[:-1]).cumsum(dim=0)
    text_list = torch.cat(text_list)
    return label_list.to(device), text_list.to(device), offsets.to(device)

train_iter =train_dat
dataloader = DataLoader(train_iter, batch_size=20, shuffle=False, collate_fn=collate_batch)

# %%
for idx, (label, text, offsets) in enumerate(dataloader):
    print(idx,"\n", label,"\n",text,"\nlen",len(text),"\n",offsets,"\n","\n")
    break
# Out:
# 0
#  tensor([2, 2, 0, 1, 2, 1, 0, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 0, 1, 1])
#  tensor([  536,   536,   598,   187,     5,    73,   463,    33,    49,    10,
#           100,   624,     1, 18453,   286, 12928,  1520,     6,     3,  3813,
#           464,   286,   117,     1,    92,   229,  6945,   986,  1103,   846,
#           316,   609,   247,   576,     2,   161,    24,    48,   121,   124,
#            34,     9,     1,  1123,    18,  3108, 11080,     5,  1266,     1,
#           272,    82,   346,     1,   309,     8,   198,    42,    19,   766,
#          1626,    20,    24,     1,   547,    87,    44,  1048,  2440,   525,
#           449,     7,    53,  1031,     6,   371,   134,   835,   142,     9,
#           119,   475,   741,     8,    29,    37,    31,   313,     2,   166,
#            59,    21,   605,  1223,   153,    26,     7,    38,  1808,   235,
#           802,    85,   486,  7618,    41,  4269,    33,    49,    10,    14,
#             1,   298,    16,    43,   575,  1611, 16906,     2, 18106,   103,
#           116, 15310,  8384,    24,    63, 15604,    58,   156,    53,  1331,
#           113, 10005,   815,     2,    11,    17, 15546,    53,    23,     1,
#            81,    35,     6,  1031,    39,     6,   710,   556,    32,   129,
#           323,  1905,   347,     2,    22,    36,    82,    38,   221,     2,
#           829,    79, 18483,   313, 19820,    53,    45,   172,   237,   112,
#          8358,    41,    50,   345,  4026,   269,   263,   113, 20694])
# len 179
#  tensor([  0,   7,  14,  28,  36,  44,  60,  68,  75,  77,  83,  99, 106, 123,
#         127, 131, 136, 149, 162, 172])

# %% [markdown]
# Let us define our text classification model

# %%
from torch import nn
import torch.nn.functional as F

class TextClassificationModel(nn.Module):

    def __init__(self, vocab_size, embed_dim, num_class):
        super(TextClassificationModel, self).__init__()
        self.embedding = nn.EmbeddingBag(vocab_size, embed_dim, sparse=True)
        self.fc1 = nn.Linear(embed_dim,64)
        self.fc2 = nn.Linear(64,16)
        self.fc3 = nn.Linear(16, num_class)
        self.init_weights()

    def init_weights(self):
        initrange = 0.5
        self.embedding.weight.data.uniform_(-initrange, initrange)
        self.fc1.weight.data.uniform_(-initrange, initrange)
        self.fc1.bias.data.zero_()
        self.fc2.weight.data.uniform_(-initrange, initrange)
        self.fc2.bias.data.zero_()
        self.fc3.weight.data.uniform_(-initrange, initrange)
        self.fc3.bias.data.zero_()

    def forward(self, text, offsets):
        embedded = self.embedding(text, offsets)
        x = F.relu(self.fc1(embedded))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# Let us create an object of our text classification class

# %%
train_dat
# Out:
# [(2, 'nite nite bday girl have fun concert'),
#  (2, 'happy mothers day she liked the poem'),
#  (0,
#   'most experts recommend that you exercise minutes most days the week two jillian videos'),
#  (1, 'entire body hurts shower hot tea and please'),
#  (2, 'going home after awesome time with the peeps'),
#  (1,
#   'now aches chills have joined the party why couldnt the cold just away had get worse'),
#  (0, 'wee are going the movies tonight see wolverine'),
#  (0, 'ack course person but think knows that'),
#  (0, 'hahaha yes'),
#  (0, 'officially done with school til fall'),
#  (0,
#   'just got back from lunch and feeling more like nap order than work but will press'),
#  (1, 'ugh crying again writing rant about tumblr'),
#  (2,
#   'happy mothers day all the moms out there special shout mommaluv and pateven though youre jehovahs witness'),
#  (1, 'going miss khyy much'),
#  (1, 'tired think imma bed'),
#  (2, 'bellacullen13 posted and its good'),
#  (0, 'kaylalee think your the only one that knows what that number means lol'),
#  (0, 'having use firefox playing and dont know why will try and fix tomorrow'),
#  (1, 'pondering lunch shanes think can already hear people whining about'),
#  (1, 'well enough mushy family talk bed stubbornly'),
#  (0, 'after show our house rocked saying goodbye soon'),
#  (1, 'really hate the mobile twitterits hard tweet with sidekick'),
#  (0,
#   'holy its super sunny friday and whitsun tube deeeesearted wish was the park'),
#  (1, 'can have some followers sad now that losing hope pressure'),
#  (1,
#   'but has out date script thats really bad midway thru his pitch catch gets all butthurt and storms out his loss'),
#  (1, 'aroundtakin easy tonight still sick'),
#  (1, 'unfortunately will nowhere near the beach have fam that area too'),
#  (2, 'iï¿½m good wanna get out the office'),
#  (2, 'thanks guys followers'),
#  (0, 'guuss last game 2moz'),
#  (1,
#   'seriously dont even work with children some how still sick groundhog friday just got worse'),
#  (2, 'what did someone and good morning'),
#  (1, 'just saw boo went back work now time hair but its going rain wtf'),
#  (2, 'agree about the redesigned q13 site looks great computer phone'),
#  (0, 'awww wanted see some more greg'),
#  (0, 'dont see where see listed cause dont'),
#  (2, 'thanks have fun work lol'),
#  (1, 'nevermind think this thing unsalvageable'),
#  (2,
#   'have lots 2do usual laundry thanking god cleaning house praising god cutting the hedge and thanking and praising god some more'),
#  (2, 'twitter officially the best way advertise something'),
#  (0,
#   'hello all new followers there suddenly lot you will take little time get round you all'),
#  (1, 'all dressed and where'),
#  (1,
#   'getting cleaning tues then getting tooth pulled thurs then gotta schedule bridge that might need root canalugh'),
#  (0, '3rd day pain'),
#  (1, 'back from miami miss south beach'),
#  (0, 'looking failure'),
#  (2, 'congratulations you two are adorable beautiful ring too'),
#  (1, 'heard icecream truck and took like shot but couldnt catch'),
#  (1,
#   'aww twiter miss you today ill post little more mea after the movie theaterahah soo coold here'),
#  (0, 'copy shipped friday shows today ill tune'),
#  (0, 'okay out for while back later'),
#  (2,
#   'and around little earlier than wanted phone rang exercise good way start the day right'),
#  (1,
#   'stupid accidentally gave honey the atomic flavored buffalo wings and now his stomach feels just awful sorry baby'),
#  (2, 'some new followers are pretty cool peeps check out'),
#  (0,
#   'better get some sleep soon she has get and sunday meetin she can pass out invites her jewelery party'),
#  (2,
#   'pacquiao fight was fun home wif fam and melissa sat today was mission ikea srsly different freeways burbank'),
#  (0,
#   'you could have played the game with this morning nobody else wanted play'),
#  (2, 'ending evening the best note will love you forever tweets'),
#  (0,
#   'not huge fan getting the middle the night change peed sheets and underpants'),
#  (0, 'nye why quiet lately'),
#  (0, 'yep they are open its sunday hours tho'),
#  (2,
#   'when balancing chair chin the sixth form common room got nothing but sneers hung those balls for good'),
#  (1, 'rest peace marshall'),
#  (0,
#   'sent donation eric and wanted put the banner but avatar disappeared when tried'),
#  (0, 'mooooooooornin how are you are your legs'),
#  (2, 'way sleepy ill watch shows latagood nite twitfam god blessxoxo'),
#  (2,
#   'woke and its bank holiday monday college got text from tom via jasons mobile earlier today hoping they turned'),
#  (1,
#   'just read they are going remake girls just wanna have fun stop hollywoodjust stop'),
#  (2,
#   'ohh that cute fishing peaceful your daughter looks focus what she doing'),
#  (0,
#   'this water horse movie totally making want scotland want water horse lol'),
#  (0, 'matt weiters first bat fly out'),
#  (1,
#   'taking underpriveledged kids the circus 2moro big day planned still aint feeling nervous right now'),
#  (1,
#   'hahahahayeah you mess that crossing and kneeling bit you will get called outjoking'),
#  (2, 'moving great especially lots them help'),
#  (2, 'its after think its time bed have good night twitts'),
#  (2, 'blue other news you will love tonights'),
#  (1, 'new dress looks sort ofhorrible'),
#  (0,
#   'last leg travels today totally exhausted but thank goodness keeping company'),
#  (0, 'off collect acquired from freecycle'),
#  (0, 'btw that song youll always find way back home hannah montana'),
#  (0, 'owwjust bit tongue'),
#  (1, 'get back tokyo manwe miss you'),
#  (2, 'did you finish twilight did and wish wasnt over'),
#  (0, 'now cleaning'),
#  (1, 'bloody servers are down work for least hours want home now'),
#  (2, 'back athens had great time budapest'),
#  (0,
#   'awww didnt see this till now and edwin just left knew you wanted some forsure tomorrow ill make new batch'),
#  (1,
#   'sorry for the delay publishing this weeks show some technical difficulties during encoding will out asap but may saturday'),
#  (0, 'hahaha think youre pretty far from maybe next time though'),
#  (2,
#   'yay thats cool aww that woulda been sweet worries though just glad you had fun'),
#  (0,
#   'going look bunch open homes today just get feel for the market think ive got lot saving'),
#  (1,
#   'one people did any wrong the world blames all the people over there this the great world which are living'),
#  (1,
#   'hayles are serious you touched his ohmygod lol aaaaawwwwwww did tell that'),
#  (1, 'have biiig headache'),
#  (2, 'nice that sounds great let know when and where'),
#  (0,
#   'lol takes some getting use just replying your email power keeps cutting out here'),
#  (0,
#   'awake suprisingly couldnt get sleep last night gave and pulled allnighter how are you'),
#  (0,
#   'the thought splitting the estate depressing course kidding dont like the thought parents dying'),
#  (1, 'girl you stay inviting but not doing followup hahaha phone call check'),
#  (0,
#   'omg please jonas brothers add extra date dublin november tried get tickets but dey were sold out'),
#  (0, 'know didnt ask'),
#  (1,
#   'had fries and arizona and thats the only thing ate today feeeeeed meeeeee'),
#  (2, 'its raining cats and dogs gdask today looks nice though through window'),
#  (2,
#   'yesterday was awesome sunny day best friends good food tons fun what more could you ask for'),
#  (2, 'thanks for the info'),
#  (1, 'wasnt good day'),
#  (0, 'same here just wanted keep going and not end ever'),
#  (0,
#   'has lost his vocie and adele laughing lol and still wondering why college week off'),
#  (2, 'holy smokes star trek was freaking awesomeeeee'),
#  (0,
#   'dont know ask carolyn also wont have the boxes empty the time you get off'),
#  (1, 'just camee back from bowling which offiacial suck'),
#  (2, 'yup gets better again after'),
#  (0, 'soooo sleepy but gotta finish this game lol gettt cavs whoop whoop'),
#  (2,
#   'always thinking about look for good place appericiate everyone who supports every site joined'),
#  (2, 'found rideyes liquor here come'),
#  (1,
#   'never does anything good school and rabbit life cycle dunno how tune giutar stuffed'),
#  (2,
#   'its good day the lake mirror the kids are happy and get clean the cabin today err two outta three aint bad'),
#  (2, 'loll course tooo love their new song toooo'),
#  (0, 'just wanted dippin dots'),
#  (0, 'thought was the only one with the tags the outside shirt'),
#  (2, 'had little family party tonight hope rocked'),
#  (1, 'bet you received lots hit from that tweet work cannot wish could'),
#  (1,
#   'onfire think letitia still trying upload the digital they were having problems before sure she will let know'),
#  (2, 'cant stop smiling the best mood right now'),
#  (2, 'god the weather london ammmmazing yet train half the day'),
#  (2, 'really wanted that gig tonight'),
#  (2, 'cant wait see boy tomorrow'),
#  (2, 'morning hope well off bed soon'),
#  (0,
#   'yeah kept rethinking because noone that knew would want with lol ended just didnt buy them'),
#  (2, 'mothers day has been good for'),
#  (0, 'nvm ill stop whatever see you 5th guess'),
#  (0,
#   'diaz did notice more men with kids stores sati heading church and sing the choir the 1st 2nd services'),
#  (0, 'can rome without ceasar'),
#  (2, 'happy mothers day sweet mum'),
#  (2, 'had good end busy day and now off bed with full belly sushi'),
#  (2, 'cant wait for prom and after prom party friday'),
#  (0, 'respond were going'),
#  (0,
#   'waiting for the bus back from cripple creek pick the twizzler town seems kinda quiet tonite rolynn719'),
#  (1,
#   'didnt read the details that may sara jayne kids show cant that exciting'),
#  (2, 'glad your feeling abit better think mine might nearly gone now'),
#  (0,
#   'duncan finally got his orders leaves for iraq september open invite stay with anytime during the year hell gone'),
#  (0, 'sam may ask odd question what might your fave animal'),
#  (2, 'serio barroca parabens may the 4th with you'),
#  (1, 'school again this time cuz sick'),
#  (1,
#   'thats sad then havent heard the new one yet sounds like ive been spared tragedy'),
#  (2, 'ready and waiting donnie love you too'),
#  (0, 'she had another song out recently but didnt get that much play'),
#  (0,
#   'heart has been beating irregularly ever since last night dont want explode implode'),
#  (2, 'how met your mother best show ever'),
#  (0, 'here are some that other tweeple recommend wwwaudiomicrocom'),
#  (1, 'too broke for cigarettes'),
#  (2, 'fine thanks wbu'),
#  (1,
#   'sigh off bed try get these crummy hrs sleep horrid hour daysmh niterzzz evry1 dont let the twitterbugz bite'),
#  (0, 'yes maam have pretty smile but you also wont eat chipotle with'),
#  (2, 'babe woo getting mine mondaycant wait'),
#  (0,
#   'last night chicago making one for the record books wrigley most likely see you there'),
#  (2, 'ahhhh the the wonderful 8track adaptor'),
#  (0, 'tried send you direct message and cant because you arent following'),
#  (1, 'oops cys place too near trouble for'),
#  (1,
#   'sad tanner wasnt invited the panthers development camp this year poor other glassers but calla was good him'),
#  (0,
#   'omg soo tired way home long busy day had fun meeting new people and catching with some people'),
#  (1, 'dont find this stuff amusing any more'),
#  (2, 'alright cool see you tomorrow thank you'),
#  (2,
#   'that was interesting show say the least recap tomorrow first must sleep work'),
#  (2,
#   'britt had she came all the way down say may the fourth with you our work done'),
#  (1, 'kind lonely when nobody will answer their phone'),
#  (2, 'celebrating mother and also celebrating legacy woman god'),
#  (1, 'just found crack baking bowlmilk spilled everywhere'),
#  (0, 'hiya hows your week been just tried you but your not following'),
#  (2,
#   'tried oprahs free unfried kfc and loved went back for another try and topped with boba and wolverinechilled with popedaveben'),
#  (0,
#   'still the bandwagon figured ive been this ride far might well see what happens'),
#  (2,
#   'follow just because dont either way they have really cool tshirts hey johno'),
#  (0, 'posting this from blogspot'),
#  (2, 'too kind jim too kind brother'),
#  (0,
#   'found some great places but might have play safer and wait years till car paid off'),
#  (0, 'geez why have obvious'),
#  (1, 'back work its too warm here today'),
#  (0, 'plans tonight'),
#  (2,
#   'goodness havnt heard lovelovelove her old stuff though the overture the underscore the best album think'),
#  (2, 'was nice meet you tonight thanks'),
#  (0, 'this twistory the making yeah stole that one from you'),
#  (0, 'did you have fun last night didnt see you'),
#  (0,
#   'andeasy when will these stores sacramento open been waiting and nothing'),
#  (2,
#   'mariahnever listen the haters have been fan for long and grateful for music cant wait the album'),
#  (1, 'what would you know about packing youre making poor lauren all'),
#  (1,
#   'stuck awful traffic the way the wedding ceremony supposed start now ughhh'),
#  (1,
#   'greg pritchard was robbed place the final bgt cry baby face got through instead'),
#  (1, 'dog suffering from abandonment issues she thinks moving without her'),
#  (2,
#   'music update before leaving check out the songs photograph air disco friends just jack stand the prodigy and enjoy'),
#  (2,
#   'ten minutes shopping demi lovatoback around demi lovatobehind enemy lines have you all seen the titanic trailer its really good'),
#  (1, 'the race was saturday night jimmie didnt great hes still 3rd place'),
#  (0, 'watching the 3rd episode jonas'),
#  (2, 'morning twitterbugsnothing like loooooooooong liein'),
#  (2,
#   'any legal studieslaw students out there twitter would love couple references cases inolving bias juries jury nullification etc'),
#  (0,
#   'moodle intro training this morning ages since ive done that and only bookings'),
#  (0, 'nope they are all sleeping cuz they live the east coast'),
#  (2,
#   'oooh lush cant sunbathe burn way easily even with sun cream great thanks lovely sunny day'),
#  (1, 'off meeting lincoln square bummer more free parking'),
#  (1, 'hey forgot'),
#  (1, 'urgh really hate that medicine'),
#  (1, 'iï¿½m really desappointed'),
#  (0, 'having dinner the crown south moreton with david and stroppy teenager'),
#  (2,
#   'the words liana corber moreover wiaih was humbling experience surprisingly had decent night'),
#  (1, 'hate when its cloudy either want all sunny raining its cloudy'),
#  (2,
#   'dear will late there good michigan well look forward chatting with you when our wakeful hours overlap'),
#  (2, 'mothers day wishes from google pretty beautiful flowers google logo'),
#  (2, 'love your show'),
#  (0,
#   'bach suggest pta for such alerts but pta generally stands for parent teacher association the might confuse tweeps'),
#  (2, '2nd aww thanks'),
#  (1, 'miss the air canada centre and andy frost'),
#  (1,
#   'saddens youre youtube has changed its just like every other youtube kid you used different'),
#  (2, 'haha def that song epic have fun listening new fnb'),
#  (0,
#   'hearts heygot your text cannae hen family are comin over ive got nae money come livi anyway xxxx'),
#  (1, 'shower then back bed sick still'),
#  (0, 'trying stay awake anyone have any tips how keep yourself awake'),
#  (0,
#   'yes just need ppl vote get out the vote ciao for now till tomorrowis anybody listening yes night'),
#  (0, 'finaly back home'),
#  (1,
#   'this really hurts and this really sucks dont know what can fix all this seriously'),
#  (0, 'come hang out wif meeee'),
#  (0,
#   'would love learn trapeze ive wanted that since was kid sadly theres place where live that teaches'),
#  (0, 'monstr may try prism'),
#  (1,
#   'miley tried voting for you and wont let vote for some reason ill try back little later'),
#  (2, 'the free fillin app ipod fun addicted'),
#  (1, 'needs job badly'),
#  (1, 'idk only stupid 7th grader'),
#  (2, 'why posting late just got back from seeing star trek was awesome'),
#  (0,
#   'was row but tried run down the front corrupted and could see you singing away'),
#  (2, 'going for lunch soon with fave cuzs'),
#  (2, 'congrats the ugh still have til the end june'),
#  (0,
#   'enjoying sunshine the park with friends pale shirtless footballers are not attractive afraid'),
#  (0, 'whos going out tonight want out'),
#  (0,
#   'what did you let guess you skipped sports and bought new pinkish outfit'),
#  (1,
#   'the weather has been super weird here looked like was gonna rain today but course didnt darnitt'),
#  (1, 'know sucks anyway you can get fake something'),
#  (1, 'stressed out will anything get any better sigh'),
#  (2, 'yeah was great outside without rainsnow cold air love the sunny days'),
#  (2,
#   'its 1000th tweet ill use simply say thank you ive met some the most givingcaring people twitter'),
#  (2,
#   'correct adore him just plucked him and put him under arm cuz was cryin all better now hahaha'),
#  (1, 'hope the train remembers the way they can bit loopy bank holidays'),
#  (1, 'soooo over schoolmaybe sickall week evil laugh'),
#  (0, 'luking for new background pic'),
#  (1, 'last night sucked too many bad dreams about spiders and rogue octupi'),
#  (2,
#   'had great night ashleigh makes good dance teacher and kicked bens butt pillow fight'),
#  (1,
#   'just learned the hard way that firewire isnt backwards compatible with firewire'),
#  (0, 'toast the morning'),
#  (0, 'snapppp look who found twitter lollll'),
#  (0,
#   'actually there was this other guy thought didnt know but turns out did know from previous party'),
#  (2, 'sigh joe sings purdy makes feel better'),
#  (2, 'appreciate you'),
#  (1, 'more mshs gotta worktoo tired'),
#  (0, 'wellnot the spurs'),
#  (2,
#   'finally got teaching load confusion cleared will teach third year sections but with catch'),
#  (1, 'sensors dont seem want last for more than days'),
#  (1, 'well rite headache'),
#  (0, 'clive its birthday pat'),
#  (0, 'chill its rihanna bob was have problem lol school all summer'),
#  (2, 'happy mothers day mom love you always'),
#  (1, 'genevaaa picture isnt showing dont think doing right'),
#  (2, 'thanks did reviews today and feel like idk anything anyways how'),
#  (0,
#   'work work work desk sea papers and the dinghy being tossed about its waves'),
#  (2, 'big hug for you'),
#  (1, 'lololi was trying that this morning but sadly couldnt'),
#  (1,
#   'justcause summer hours say our day ends 1pmdoesnt mean really get leave'),
#  (1, 'whaaaat what about your house youve been working hard'),
#  (1, 'its dead'),
#  (2, 'happy moms day your moms'),
#  (2,
#   'ill see you again yeah its you guarantee you will dont want wait long not seeing you fruit basket hahaha'),
#  (0, 'plz dont fall love with tokyo and never come home'),
#  (0, 'knew horse called dollar too'),
#  (1,
#   'whew literally shopped till droppedand sprained ankle ughdo you see the sacrifices make for you'),
#  (1,
#   'know how you feel darian with bam and missing him terribly and wont see him until sunday'),
#  (2, 'but omg mummy bought icecream'),
#  (0, 'where arre you going study'),
#  (0,
#   'actually sweden the ikeas have rooms stay the night not here though ill have stay across the street'),
#  (1,
#   'student just walked balling she just witnessed her dog getting hit the street dont know what cheer her'),
#  (0, 'been following lol just dont paying attention little mylan'),
#  (0, 'guess youre responding about thats the case'),
#  (2, 'congrats dave anna surprise proposal the enzian theater orlando'),
#  (1, 'cant feel the weekend fever anymore when everyday day off'),
#  (2, 'great song even cant understand lol'),
#  (0, 'work again when the weather beautifullll'),
#  (1,
#   'its too hard guy peicing person and shoud change cause mine hard change'),
#  (0,
#   'didnt catch the jonas brothers facebook webcast already ended when logged facebook account'),
#  (0, 'soz ideas that reason didnt take geography would fall asleep well lmao'),
#  (0,
#   'just spent all day putting trampoline but now too tired use very cool though'),
#  (0, 'tom graduated today'),
#  (2,
#   'not living just trying earn the grocery money enjoy eating least once day'),
#  (2,
#   'working several book projects that are due released within the next few months need extra pair hands its all good'),
#  (1, 'cant figure out the empire puzzle stuck'),
#  (2, 'way work cant bothered'),
#  (1, 'such terrible day only six now'),
#  (1, 'omg man ill pray for'),
#  (2, 'hahah okay then thanks for this short explanation'),
#  (0,
#   'the mood listen some reg stuff sir told used huge fan mine but now seems youve forgotten songs'),
#  (0, 'wants sunbathin'),
#  (0, 'concert tonight chackin out and not coming tomorrow'),
#  (2, 'brings sooo much joy show great song 5z3oq'),
#  (0,
#   'haha night man and but sure ill meet her again lifetime fact willno doubt about'),
#  (1, 'saying goodbye papa'),
#  (2,
#   'happy frickin birthday try not too bitter about sharing your day with your lovely wife and all other mothers out there'),
#  (2, 'thanks got hold someone there who knew their stuffat last'),
#  (1, 'have broken wrist'),
#  (1, 'holy wow think couldve slept all day soooo tired'),
#  (1,
#   'she should keep her crown and shut her mouth then shell know what nonjudgmental means'),
#  (1, 'looks can deceiving'),
#  (1, 'cant sleep feening for cigs horrible'),
#  (2, 'see you later lovely ladies good love you millions'),
#  (0, 'unopened pack goat cheese starin the face starving din not til'),
#  (1, 'with bff chrissy22 glad she got that dog out here lol stomatch hurts'),
#  (0, 'going bed soon'),
#  (2, 'caww that sounds good hope youre right'),
#  (0, 'muthafuckin win'),
#  (1, 'thanks hope been playing dmc4 like times kinda sick hehe'),
#  (0,
#   'went bella coffee roasters today and asked for job the person needed speak holiday'),
#  (2, 'twittering like boss thanks savvv'),
#  (0,
#   'not doing cbeebies epg any chance are you hehe need pinkyponk crash warnings your journey home long'),
#  (0, 'the office for abbies second round shots'),
#  (1,
#   'miss the jokes and making fun ppl and throwing ideas for songs movies and shows eachother the most thatll never away'),
#  (1,
#   'naplan testing tuesday wednesday thursday afraid about the maths one english not much'),
#  (1, 'miss you asia come visit when you have time'),
#  (0, 'listening some brandynever say never'),
#  (2, 'favorite curling iron broke'),
#  (0,
#   'playing bubblewrap her iphone over and over and over again still beats working'),
#  (2, 'working vacation thailand getting more excited every day'),
#  (1, 'pmg very upset just relasie hugh laurie isnt ohh'),
#  (1, 'not friends with anyone anymore'),
#  (2,
#   'woohoo nothing says hot date night than squeegee lol watching dora noggin with 2yr girl hubs work'),
#  (0, 'you too cloudy day here madrid typical spring day'),
#  (0, 'calling your roommate'),
#  (2, 'love you though'),
#  (2, 'joke puppy maddie looks exactly like maui shes cute'),
#  (2,
#   'thanks for the followfriday recommendation were actually careerbuilder though'),
#  (0, 'monday morning lets whip out some code today'),
#  (0, 'its friday and dont have job for the weekend'),
#  (0,
#   'its friday every1 has plans but memy mom laser tagging friendshahamy brother outmy sister and dad working mebfalone'),
#  (1, 'awww sorry what kind fish did you have'),
#  (2, 'wasnt bored really redd converse love converse'),
#  (0,
#   'always choose good guy even know its only game feel bit bad doing evil things'),
#  (2,
#   'not watching star trek tonight but heading lovely dinner and fun board games night with'),
#  (2, 'happy birthday keshia keshia beshia'),
#  (0,
#   'well the beginning new week and guess where the office 4more days till friday'),
#  (0,
#   'welcome first german follower mother hermine from the sudetenland and came sweden refugee'),
#  (0, 'the pink straw also makes you manly'),
#  (0, 'was yeah work hrs how you'),
#  (0,
#   'charlotte should there will another thrown sure but this one will with american family'),
#  (1, 'why cant buy the nokia n97 amazon says cannot ship this address'),
#  (0,
#   'yeah shes done several times dumerils boa did few times prob just wonder hognose needs bigger food'),
#  (0, 'hahahaha definitely still writing'),
#  (1, 'you make baby jeebus cry'),
#  (0, 'granted wont that either'),
#  (1,
#   'the eye doctors had bring trinity with cause mom fell down the stairs today broke her toe ugh'),
#  (0,
#   'diva know knowlol that the one song that stops tracks dancefloor just cantlol'),
#  (1, 'damnit have run out candy coated books'),
#  (2, 'call later can tell you all about the weekend easier over phone'),
#  (0, 'cough cough hack hack'),
#  (0, 'little hungry nice bowl spicy lentil soup should fill the gap'),
#  (1, 'not happy bunny'),
#  (1, 'last day worksick the bone'),
#  (2,
#   'wow great know piece software ensures our timely project delivery productnamingrulez'),
#  (0,
#   'photo martwo omg love you accadentally deleted this photo yay hes beautiful'),
#  (0, 'youre welcome how much longer until its colored'),
#  (1, 'oooh sorry late smashed'),
#  (0, 'may human kindness day'),
#  (2,
#   'googled engagement rings this the exact ring wantit was the 1st result too sigh love'),
#  (1, 'soo tired still kinda angry that missed the concert'),
#  (0, 'workthinking about things when should working'),
#  (0,
#   'wondering how big the rumored new large screen kindle will and when can start seeing k12 textbooks'),
#  (1, 'have you the email from miley want write with her but cant'),
#  (2,
#   'yes siri just acquired master arts christian ministrya loooooong journey completed todayso thankful'),
#  (1, 'hungry and have nothing eat'),
#  (2,
#   'nope its for the 1st time invited her ssm and she very graceful accepted'),
#  (1,
#   'had unhook twitter from facebook because all facebook cronies were complaining'),
#  (1, 'think niece got sickee lame'),
#  (0, 'the park its raining'),
#  (0, 'not going'),
#  (0,
#   'the airport philadelphia the moment waiting for the plane leave about hour just six more hours plane'),
#  (2, 'ooh love sweet potato fries should definitely'),
#  (0, 'ive got cold too sucks and were awesome ipswitch'),
#  (1,
#   'rope witdrawal full effect one tie teaching demos one play with but worst all one play with'),
#  (1,
#   'like cheesecake brownies miss cheesecake brownies and the walmart closest doesnt have'),
#  (0,
#   'friend cliff has the tix have wait him you can ask trent just let you know over all else'),
#  (1, 'mcfonalds roulette lose they forgot mygrilled snack wrap'),
#  (1, 'slowly reallizing how this burn got work hours ago really sucks'),
#  (2,
#   'sleepy nowgnight happy mothers day your mother mama mommy whatever you call them lol from mie'),
#  (0, 'they are arent they'),
#  (2, 'goooodnight everyone and happy mothers day all the mothers out there'),
#  (0, 'time hit the study notes prep for fridays exam'),
#  (0, 'gonna miss thick blood next friday'),
#  (0, 'about duster shoppping greenhills with mom for balikbayans'),
#  (1, 'miss rollerblading down shoreline'),
#  (0, 'morning off school ickkk'),
#  (0, 'edge left off the contributors list this months issue ffs werd'),
#  (1,
#   'twenty minutes call you would think that the person would mention there already trouble ticket investigating the issue'),
#  (1,
#   'when someone edit your designs called plagiarism right but what can you tired exhausted and dissapointed'),
#  (0, 'oof perhaps its time start moronmonday shoutout meme'),
#  (0, 'was wondering about your sanity for bit there dear'),
#  (1, 'maaan was pain come wanna come eat some lol rolls eyes'),
#  (1, 'doing fieldwork databook slept awkwardly bones all sore'),
#  (0, 'heehee love you tired'),
#  (0,
#   'jamie sean cody for some angry jamie sean cody wouldnt piss this one off hey there guys'),
#  (1, 'maybe you have memory sucks'),
#  (0, 'why not united kingdom'),
#  (2, 'that lovely'),
#  (1, 'probably because its getting chilly here'),
#  (2,
#   'its beautiful day but stuck inside playing zelda ive gotta play least hrs today'),
#  (0,
#   'youve got love fly tippers worst ive seen dead mule dumped holmbury hill'),
#  (0,
#   'funny but right like bsb but not fan than love much better tupac tlc2 bad theyre not singing anymore'),
#  (0, 'brother planning moving vietnam and staying there forever'),
#  (1, 'and see puppy dont want there alone'),
#  (2,
#   'happy great glowy ravey beery night now smokey pizzary night with cool friends and love liz'),
#  (0, 'one new follower'),
#  (1, 'skies miss you too isi never want come homeseriously'),
#  (0,
#   'thanks everyone unfortunately nothing can done the sales speak for themselves and that doesnt convince diamond nothing will'),
#  (1, 'omfg whyyyyyy not that sucks and r18 wtf tai getcho asses down here'),
#  (2,
#   'the mums cake done now need make good luch and tomorrow will amazing mum day'),
#  (2, 'excellent looks like youll have some twitterific competition'),
#  (0, 'dude there sun here'),
#  (0, 'ive just realised followers yay'),
#  (2,
#   'just for reference dont own that dress either sounds like was good fopp buy then'),
#  (2,
#   'either way you always tend make followfriday list sweetie you rock that much'),
#  (2, 'best friend away special olympics she said she was gonna bring'),
#  (0, 'gov gov how are you'),
#  (1, 'cant believe you tweeted that was our special moment'),
#  (1, 'stuck traffic the the way costa mesa'),
#  (0, 'know right'),
#  (0, 'going outro peace'),
#  (2, 'sure youd consider they offerred the right price'),
#  (0, 'starbucks'),
#  (0, 'heading out relay the belfast marathon'),
#  (0, 'sats what the its just around the corner'),
#  (1, 'longer have ticket for'),
#  (1, 'updating old ipodsadi miss orange nano'),
#  (0, 'what going without skype haha'),
#  (0, 'more high school'),
#  (2, 'its gonna great week dallas next weekend'),
#  (0,
#   'kinda done trying ugh well was worth the effort long day tomorrow night tweeters'),
#  (0, 'now took wrong turn after besi now jam city center'),
#  (1,
#   'unfortunately people work let down now having bad morning its official but revenge dish best served cold'),
#  (0, 'now cassidy butcking that lol cant ever win'),
#  (0, 'back work today but dont even mind'),
#  (0,
#   'dont think ive ever been this early sunday while meanwhile the bigweekend awaits'),
#  (2,
#   'watched wolverine yesterday spur the moment kinda thing awesome proud that south african director did that'),
#  (2,
#   'yay happy mothers day screw burnt breakfast bed ill take some erniehalter live'),
#  (2,
#   'getting new cellphone wednesday the voyager its soo sweet cant wait that long though'),
#  (1, 'was eating manderin but its all gone now'),
#  (2,
#   'most kids love dark hair some say that dye too much and they never know what color its going yea hahahahaha'),
#  (1, 'that doesnt sound good better get checked out'),
#  (2, 'lovin the clean shaven flowers looks young reminds that getting old'),
#  (2, 'everybody welcome hello nicole'),
#  (0, 'adding comments for friends want sum'),
#  (0, 'have work tonight'),
#  (2, 'culture day love telling you graf culture the study'),
#  (0,
#   'really rather drunk drunk thoughts how getting work tomorrow loz alive does gandhi read comic books will never know'),
#  (0,
#   'circus was fun dont have any hope getting out the parking lot havent moved min'),
#  (2,
#   'first thought bar life meant you were partying nonstop catch for the last yearslol shoulda known better'),
#  (2,
#   'reading cryin reading laughin enjoying the ride while being enlightened and inspired letters young sister thx hill'),
#  (1, 'annoyed the ppt didnt save changes when explicitly saved'),
#  (2,
#   'just had great talk with grace about how awesome god and how worksthat somehow started with how remote controls work'),
#  (0, 'almost everyone can suck right about now ive had here with people over'),
#  (1, 'gotta say all that'),
#  (2, 'thanks for the recommendation'),
#  (1,
#   'thats weird seeing your myspace page without there had delete page though'),
#  (0, 'lol why are they drumming there'),
#  (1,
#   'would like remind people that out kansai scene and whatever the current issue like have had nothing with'),
#  (1, 'that may still dont like hearing his name much blackhawks canucks'),
#  (0,
#   'wanna see that movie keith with jmccartney looks sooo good but none the video stores here carry'),
#  (0, 'have use the bathroom'),
#  (0,
#   'drove mazda rx8 today and boy that car fun sadly though dont find car that much fun any more'),
#  (0,
#   'well yeah but mom doesnt wanna drive all the way sac were that far away'),
#  (0,
#   'how you like them apples from the movie rio bravo good will hunting make lot more sense now'),
#  (1, 'imposible amar starbucks'),
#  (2,
#   'thanks for asking sarah glad tomorrow 5th holiday here korea will have some rest and will right rain'),
#  (0, 'happy birthday mel miss you the'),
#  (0, 'ahh man and off next weekend'),
#  (2, 'happy mamas day ladies have good day'),
#  (2,
#   'yeah thats trueee cant wait till the tour dvd comes out that tour was epic and the backstage material hilarious'),
#  (1, 'nobody likes feel low priority'),
#  (1, 'feel actual heartbreak gates last night'),
#  (2, 'lmao yeaa iight shuld put tha flick head juss joke'),
#  (0, 'mmmm yes please'),
#  (0,
#   'mind playing tricks meor could either way this ish mind heavy and sleepy'),
#  (2, 'happy mothers day mom all the other mommies moms have qood one ladies'),
#  (0, 'you makin'),
#  (1, 'weekend along with the summer here why feel sad'),
#  (0,
#   'computer slooowww this morning think its sign that should home and play yard'),
#  (2,
#   'eyedea love lastfm but find lot easier and more content spotify add you like'),
#  (1, 'cant sleep ughh have registration tomorrow this suxs shooting star'),
#  (1,
#   'followillfriday sucks because while was teaching people how nice you were drooling over notion'),
#  (0,
#   'working tomorrow all day cant anything tonight whats the plan for saturday'),
#  (0,
#   'rankin yep you buddy long time talk hows things and see your cat still like sinking fangs into your ankle lol'),
#  (2, 'apuya hey hey andrew haha well happy mothers day your mum'),
#  (2, 'going bed happy mothers day people'),
#  (0, 'one know likes boiled peanuts'),
#  (2,
#   'all wellthat ends well unless course well times the power three the sum ends being all'),
#  (2,
#   'sitting mels house just finished eating mcdicks laughing all the dumb stuff said tonight ready for bed think'),
#  (0, 'just wish would send bruh wont til dont waste erection bot'),
#  (1,
#   'they recorded and sent people they obviously meant for get out there but they didnt feel bad'),
#  (0, 'yeah its bit 80s silly points but love'),
#  (2,
#   'think that normally are drawn people familiar similar the cougar thing for some quick fun'),
#  (1, 'snotty nose poorly chest this not good'),
#  (0, 'looks exactly like when get that guitar hand'),
#  (0, 'aaaargh help its conspiracy lol how are you today lizzi'),
#  (2,
#   'hugs love you mamabear happy moms day case dont see you around tomorrow'),
#  (0, 'did back pakistan'),
#  (1, 'what dreary day where did all our sunshine'),
#  (0, 'can you give the link for the kimba diaries please'),
#  (2, 'believe its bed time knighty knight'),
#  (2, 'love dawn the replicants love music monday'),
#  (0, 'any chance getting see this can there within hour'),
#  (2, 'thank you btw ure wondering you can check out the fuel brand here'),
#  (2, 'wow thats cool'),
#  (2, 'saw yesterday pretty good'),
#  (2, 'wine and saginaki with friends good times'),
#  (1, 'youre harlem where jealous right now miss living nyc'),
#  (1, 'bored have headache'),
#  (0, 'carter the video private cant see'),
#  (2,
#   'yeahh very happy with pendant and hope see you future fairs good mini muffin'),
#  (1, 'could hit aim here cause mad bored nuttin'),
#  (2,
#   'dam just finished watching prison break the final breakomg dont think ive cried hard for showfinally understand the finale'),
#  (2, 'thanks hun next time well all again'),
#  (0, 'why thank you might just take you your offer'),
#  (2, 'happy hour for today'),
#  (1,
#   'will very hard back work this morning straight days disneyland tends that'),
#  (2,
#   'dont you just love the butteflies your stomach feeling ano man yun kaya yan'),
#  (0, 'lokelani have idea'),
#  (0, 'dont even know what sporting social enterprise means'),
#  (0, 'doing the andy dance the one fonzie gomez show haha'),
#  (0, 'lol thatll teach blindly trust amazon search results without reading'),
#  (0, 'and the city love tucson the 18th most miserable'),
#  (0, 'lol clever extremely jealous the amount followers you have only have'),
#  (0,
#   'want part windows clubhouse but spaces blog random and not the place where share windows stuff'),
#  (0, 'you really think was that awesome well have discuss'),
#  (0,
#   'little foster kittens are getting bigchubba and winston are going missed when they get amazing homes'),
#  (2, 'youre welcome course'),
#  (2, 'the sunset view beautiful from room'),
#  (0, 'yes know school reports would say must much better well just time huh'),
#  (1, 'yepsjust for today though badly wanted some geekshopping'),
#  (0,
#   'hours refusal upon realisation that tomorrows morrissey gig brixton postponed only been looking fwd that for monthsish'),
#  (0, 'woken finally after long night out tea toast and coming'),
#  (1, 'awww omg garbo fake playing during one the songs haha'),
#  (1, 'have headache'),
#  (0,
#   'got the cofo late didnt close today will close mondayback out meet buyer tonight show few homes'),
#  (0, 'cant send the dream story twitter sending bebo mail'),
#  (1, 'sick kid trumps advance planning bummer'),
#  (2,
#   'writing out mothers day cards mom aunts and amyyyy cant wait for her mommy'),
#  (2, 'hella worth even you dont need the full now'),
#  (2, 'hehe now smiling but still gotta make'),
#  (0,
#   'wont really get break till custody issue settled and ive moved another month least'),
#  (0, 'lol said look out for you but was canberra'),
#  (0,
#   'catching tweets saw acs promo your new blog before yours knew immediately would yours the title'),
#  (2, 'good hear'),
#  (0, 'you have cents can buy share stock probably cents tomorrow'),
#  (0,
#   'this original from yours truly you want become wealthy learn the things most ppl say they dont have time for'),
#  (2,
#   'want dog cat something want something unconditonally love thats not materialistic family memeber'),
#  (0,
#   'credit left mobile sorry brit pounces back thanksss tania for the epic photoshoot'),
#  (0, 'should really try different pose some time'),
#  (0, 'tegan and sara fan follow them'),
#  (1, 'linda what you mean your last post doesnt sound good'),
#  (0, 'feel sorry for your nails lol feel fine thank you'),
#  (1, 'that annoying what gear ill take off your hands'),
#  (2, 'download movie ben alien force cool movie'),
#  (1,
#   'sorry love had left overs but come through sat casa for tons birthday well have tons food'),
#  (0, 'grats aaron and christine'),
#  (0,
#   'unless you mean the hours week use for sleeping yeah suppose could use those'),
#  (0, 'chillin with kealie'),
#  (1, 'having problem with photo here twitter amfcant see face'),
#  (2,
#   'its cool glad everyone had nice date night maybe one day ill get one too'),
#  (2, 'happy mothers day all the mommies'),
#  (1, 'aww anyone see hollie steel bgt tonight wharra shame'),
#  (1, 'pandora blocked work bummed'),
#  (2,
#   'was baby bros last time singing front his school proud him but when did get old only'),
#  (1, 'sister graduating too cant afford buy here anything'),
#  (2, 'just back from bingo wfamily won over fun night'),
#  (0, 'will your for little while tune you want wwwsoompiradiocom'),
#  (1, 'lots reqs today fun'),
#  (2,
#   'installed ubuntu office lap yaaaaaaaaaaaay install under windows feature rocks awesome ubuntu excited'),
#  (2, 'planning her week its going good going get lot stuff done'),
#  (2, 'waves make all again'),
#  (2, 'listening maroon songs about jane one favourite albums time'),
#  (0, 'bed mister need your beauty sleep'),
#  (0,
#   'pictures cassie from the crawfish boil make smile real big also desktop still fail ultimate fail hates'),
#  (0, 'think ive finally reached the point life where need nasal hair trimmer'),
#  (1,
#   'hate the fact that hours away from you tonight and tomorrow well miles apart wish you were here'),
#  (0,
#   'haha ofcoooursee you its pretty much must and pluss its dress night jst added incentive'),
#  (0, 'just arrived about fellows cant see girl'),
#  (2, 'that sounds cool post video'),
#  (2,
#   'agreed though eclipse apps hinder collecting the heap dump catching oome had muck about jconsole'),
#  (0, 'watching twilight and eating potato salad'),
#  (2, 'haha better drunken tweeting you mean'),
#  (2, 'sweeny todd awesome movie the best'),
#  (2, 'hope your weekend was fabulous anything interesting'),
#  (1, 'hate having headrush'),
#  (0, 'sunny day sunny outlook'),
#  (1, 'slightly burnt challah the proof the eatin though'),
#  (0, 'merlin wasnt too bad already watched course'),
#  (2,
#   'thanks lot youre very kind just got back from nice drive the such fun car drive have nice day'),
#  (0, 'hanging with the cousin'),
#  (2, 'thats cool thanks'),
#  (2,
#   'man now its rainingseatbelt now buckledthanks bates for wishing have blow out and flip and burn'),
#  (0, 'didnt get the job berry line after all'),
#  (2, 'crawling into bed super happy that the penguins won tonight'),
#  (0, 'still pjs but haveto get dressed cuz going see dancing ice live'),
#  (0, 'seventeen today and trekking from chorleywood see and cambridge'),
#  (2,
#   'have great weekend mononoke may tweeting from inside the movie theater either monday tuesday lol'),
#  (0,
#   'daarling haha yah its walking distance from house mission tiki drivein haha every summer like every weekend'),
#  (0, 'would think youd want follow'),
#  (2,
#   'show was amazing cold out now hope can give victoria card and get dvds back'),
#  (0,
#   'fever awesome tonsils are swollen cant even eat solid food still location the pictures rule though'),
#  (0, 'listening broken lifehouse repeat'),
#  (1, 'hungover what crazy night also the bad books with mother'),
#  (0, 'halu for dinner second time this week'),
#  (1, 'did many things but missed tweeting'),
#  (1,
#   'sadly doesnt was hopeful after american doll posse too its just blah and vacant dynamic'),
#  (1,
#   'dont think that feeling too well all the sudden tired but scared fall asleep cuz know will wake sick'),
#  (2,
#   'laptop broke who wants help girl out and take best buy this weekend please ill feed'),
#  (1,
#   'bummer missed taylor swift the today show those were only plans for the day'),
#  (2, 'happy nurses week its our first one rns'),
#  (0, 'dont have quit smoking'),
#  (0, 'that plain sux kinda like cheers goin off the air'),
#  (2,
#   'hope they rerun this nerdprom later sounds like theyre having lots fun thanks all for the playbyplay'),
#  (2, 'backhad great mad monday meeting tomorrow'),
#  (1,
#   'jus skinned knee wat hurts lyke hell tho its always tha little ones that hurt tha most'),
#  (1, 'cant give blood within year getting tattoo cant giveim gutted'),
#  (1, 'minutes boarding hours home window seat'),
#  (2,
#   'just came back from first city rooftop party man even when youre next the new yorker bldg still gets pretty windy there'),
#  (0, 'confused about guyhes great but why pushing him away'),
#  (1, 'know buffie sitting office instead going see kane major bummer'),
#  (2,
#   'were done much for them then brazilians but meh think they love the other countries more then the'),
#  (0, 'has hour left revision'),
#  (2, 'good moring gonna take shower fix hair and then going out'),
#  (2, 'wowthat must sooo cool'),
#  (0, 'going out the rain'),
#  (1, 'which means spend more time alone than with friends and family how sad'),
#  (2, 'ahhh yay getting into knockin lot out'),
#  (1, 'where art thou miss you'),
#  (2, 'thanks followed back'),
#  (0, 'loved that movie and miss raul julia'),
#  (2,
#   'thx for following teach some chinese lessons youtube pls feel free have look wwwyoutubecomchineselearn'),
#  (0, 'boystown ill leave for eastwood 3hours'),
#  (2, 'apparently havent tried the site tho maybe will get better results'),
#  (0,
#   'like and all butttt your not going have the august 7th concert which hurts feelers'),
#  (0, 'hugs sorry man were rich buy ticket now'),
#  (0, 'work full weekend vengaboys zane lowe wolf from gladiators memories'),
#  (2, 'sorry for your loss know how you feel she was lucky cat'),
#  (1,
#   'absolutely gutted that not going badu tonight you guys have fun just got home and need head downtown now this heat'),
#  (0, 'phone with tyson'),
#  (0,
#   'more packing cleaning and getting done last day this apartment this time tomorrow will storage'),
#  (2, 'wow love thanks'),
#  (0, 'dude letters are the new currency think were rich'),
#  (1,
#   'she maybe that was our first mistake not everyone cool brown nose moment'),
#  (0, 'waiting for jonas come'),
#  (1,
#   'hate being reminded how weak eyes are overdid reading today theyre sore going rest sigh'),
#  (1, 'lucy has upset tummy and sore leg'),
#  (0, 'but but but want steak'),
#  (0, 'last day college today'),
#  (1, 'having bad dayweek'),
#  (2, 'hey there its glorious morning mondays animation mode'),
#  (0, 'lamania have mask whoooops'),
#  (2, 'people you love wait not there'),
#  (2, 'outta here see you guys later tomorrow happy moms day again'),
#  (0,
#   'ooooo wasam using the iphone version just use the web and sometimes twidget mac'),
#  (2,
#   'going work amazing charity event for big brothers big sisters dont mind working its for good cause'),
#  (1, 'have stupid headache day off'),
#  (0, 'stupid its star wars day may the 4th with you'),
#  (0,
#   'about the garden weeding mulching cutting down and anything else that find'),
#  (0, 'workyy trying get point with all that have smile 3linman tonight'),
#  (2, 'but its pretty least think need catch some sleep soon though'),
#  (1, 'bored bff doesnt want hang out'),
#  (1,
#   'need shopping boring day tdaynothing dooo college tmrohow excitin wish twitter was simplified for'),
#  (0,
#   'did shed few tears watching the preview for next weeks medium scared addicted this show love'),
#  (0, 'looking forward the show tonight cant wait for mate'),
#  (0, 'mmm btw was just talking you you were gone'),
#  (2, 'nothing important just like look like that its old hairstype actually'),
#  (1, 'yst are very burnt sorry back front burnt'),
#  (0, 'yeah and liljessx did only ones that care for'),
#  (1,
#   'and maybe you will get the statue and sainthood you are seeking winwin for all cant victim like your people'),
#  (0, 'money honey hehe too soon sorry'),
#  (2, 'greeting again every momma happy mommas day'),
#  (2, 'working bank holiday but dont mind its all good fun'),
#  (1,
#   'prolly e71 cant think anything else and unfortunately not singtel customer'),
#  (2, 'rofl love you too trina'),
#  (2,
#   'surprise party today parties tomorrow funfunfun but need finish bug project'),
#  (1,
#   'dont like the possibility the left side brain hurting because the thing called shunt and possible death'),
#  (2, 'good day all lets see what can get accomplished today together'),
#  (2,
#   'great mood todayyyyyyyyy super excited for the game tonight not excited one year older tomorrow'),
#  (2,
#   'awesome congrats completing cant believe you cycled the distance cottage though day'),
#  (1, 'miss you'),
#  (0,
#   'thanks unfortunately the had probs with his satellite provider even though his looks great its basically useless'),
#  (2, 'freakin hawt guys this restaurantwhere eating dinner with father'),
#  (1, 'saaaaaaid haha kinda makes sad though'),
#  (1,
#   'for all the effort and time put into some these relationships with people you learn enough not trust anyone'),
#  (2, 'problem these boxes are made for undernourished professionals'),
#  (2,
#   'will see you guys the philippines that would the coolest thing ever always wanted one your concerts'),
#  (0, 'cant did forget say that hahaha wouldnt able get home'),
#  (2, 'sowwy lover you'),
#  (0, 'always feel sickly when wake well got busy day ahead yippeee'),
#  (1,
#   'first ever dropped call mobile call less being charged for data even though have data pack'),
#  (2,
#   'def see tonight must get some photos didnt get any yesterday lol and thanks for doing please dont forget'),
#  (0, 'also believe some things are meant happen'),
#  (2,
#   'the end the magic and dream wins along with swaying back and forth within site sleeping mommy'),
#  (0,
#   'dont care what kind graphics engines video games have nowadays they are nothing compared the oregon trail and carmen sandiego'),
#  (0, 'trying work'),
#  (0, 'peekaboo can see you'),
#  (0, 'most time gtalk pls make follow count'),
#  (1, 'what about vote every day for you'),
#  (0, 'cool going like bunchh shows this summer broke now though haha'),
#  (1, 'musicmonday agree its just excuse for tweet music for hours end'),
#  (2,
#   'hey babe nothing much tryin see what imma work today lol look like the load isnt bad'),
#  (0, 'boyfriend out with friends tonight dont know what with evening'),
# ...
#  (0,
#   'was saying the same thing yesterday droped tweets the smarted thing bussiness wise but can find real people'),
#  (0, 'yeah must say was very good haha'),
#  (2,
#   'just remembered some hopefully good news coming hopefully soon from someone know once again may the happydance commence'),
#  (2,
#   'back later happy mothers day all the mothers the world ï¿½ god loves all'),
#  (0, 'ooc well'),
#  (0,
#   'castlebar doesnt have going galway see the movie but that could next week the one after that'),
#  (0,
#   'anyways have severe headache ryt now jst love dis cup tea made self its makin the headache away'),
#  (0, 'sooo hyper and dont even know why hahahahaha'),
#  (0, 'hey twitter hows going let know how your day going'),
#  (1, 'hate being sick make soup'),
#  (0, 'will but you will never know its'),
#  (0, 'not again feel better soon'),
#  (1, 'lula not feeling well'),
#  (0, 'eww what doing atm'),
#  (1, 'theyre the bottom the thing and arent moving all feels bad man'),
#  (2,
#   'glad you liked hes done loads arrangements but that was the only one could find blip'),
#  (0, 'mom gets paid'),
#  (2, 'they never cease amaze'),
#  (2, 'thanks for the morning laugh you are just too funny'),
#  (1,
#   'rachinea you said you goodbyes and hugs dad left around the morning woke empty house pretty scared'),
#  (1, 'the theres confuse'),
#  (0, 'people ask lot and plus thought contribute sykes the trending topics'),
#  (2, 'really good night'),
#  (2,
#   'because pop culture beautiful also you cant pull weeds wrong promise you can practice yard you are nervous'),
#  (0, 'dionusia made'),
#  (0, 'happy mothers day'),
#  (0, 'look following you'),
#  (0,
#   'actually like almost everything about job right now except the part where its not permanent'),
#  (2,
#   'awwww thought itd yummy experience will try next time kapag magkakasama ulet tayo nila mapet'),
#  (1, 'what happened afraid missed large part the story'),
#  (1, 'this picture from last year freshman year how miss thos days'),
#  (1,
#   'what you think snapshot befoooore the vid recording seesmic the ladies dont look like freaks just sayin'),
#  (1, 'just got back from the bbq got sunburn legs well sore'),
#  (0, 'really really ready'),
#  (1, 'think may have ruined friendship this week getting carried away'),
#  (0, 'almost dun choreographing the dance'),
#  (0, 'maybe going the movies later'),
#  (0, 'supposed great weather today 2moro just luck stuck work both days'),
#  (1,
#   'going forgo pub night with the wife tonight tough week for both and neither really for plus our neighbor died'),
#  (2, 'kks have fun eating lol remember shaun loves you haha'),
#  (0, 'would love talk you but live england unfair'),
#  (0, 'bye for now people'),
#  (2,
#   'its goin good takin easy ths weekend preparing for the big events comin for girls inspire great things'),
#  (0,
#   'ill back later today got plenty gold but willing help you out you need anything all'),
#  (0, 'you should add your blog cmf ads'),
#  (0,
#   'glad you threw the tantrum was going but dont know her well enough yet was she apologetic darn her'),
#  (0, 'the manics gig toasting your speedy recovery sorry you cant here'),
#  (0, 'lucky stuck the rain'),
#  (1,
#   'boring starting work weekend soon 1st need get tim coffee can make through this night shift'),
#  (1, 'its sad day when christian lacroix has file for bankruptcy'),
#  (1, 'this song slap you face 5jib6'),
#  (1,
#   'cong govt was ruling karnataka cauvery wouldnt have found mention truly our politicians have integrity'),
#  (2,
#   'morning all first tea the day and just about record the voiceover for documentary about modern druidry good times'),
#  (2, 'what great day for massage book your appointment today'),
#  (1,
#   'currently 52ï¿½ msla not cloud the sky humidity gonna get into the 80s today and imworking'),
#  (1,
#   'trending topics twitter used useful now theyre just like middle schoolers passing around notes cause class boring'),
#  (0, 'ahhhhh fml classic crime sold out'),
#  (2, 'thanks for following doing much been long time since last chatted'),
#  (2, 'happpppy mothers day'),
#  (2, 'for one welcome our new cybercriminaloverlords'),
#  (1, 'wondering what happened the sun may grey'),
#  (0, 'has work this afternoon'),
#  (0, 'check the high scores today currently have the no1 slot'),
#  (1,
#   'what cant believe had find out this waydont you ppl contact family first sad who was it1'),
#  (2, 'fillings the good two more appointments'),
#  (1,
#   'tired today think gonna take nap before our friends come over tonighti miss him and wish was off restriction already'),
#  (2,
#   'training studlife fost tiberiu lovin noi aflat sunt imbecili peste tot fun'),
#  (2, 'doing uni work all weekend fun times'),
#  (2, 'loves that the first monday may bank holiday'),
#  (1, 'wish could get nails done stupid job'),
#  (0, 'excuse msgomez who said you could leave'),
#  (0,
#   'acquiring centos live now where did put memory stick would like boot from that wonder left home'),
#  (2, 'thank you jonas'),
#  (1, 'cantttt grandparents are here'),
#  (0, 'one final down two'),
#  (0,
#   'will see theres used organ shop there let you know but why not just sign ejammingcom and rock out'),
#  (2, 'now has followers congrats'),
#  (2, 'dinner smells goodman hungry sunny outside wish was wonderland'),
#  (2, 'new supernatural tonight'),
#  (2, 'thanks for finding have wonderful evening'),
#  (0, 'just got booked ticket athens'),
#  (2, 'cool looking forward now'),
#  (2,
#   'saw fiddler with topol the girls looooved next month annie 7th row cant wait trip the music store for fiddler sheet music'),
#  (0, 'should not drink cheap wine'),
#  (1, 'your ani sorry'),
#  (1,
#   'reaons not worth drunk for reason depressed about revision nothing happened reasons worth itmatt after that dunno'),
#  (2, 'rob got lucky that game beat'),
#  (0,
#   'worried about sisters guinea pig hope stalin makes through tonight you can baby'),
#  (0,
#   'soaked the rain seconds and wasnt even hiking miles with miles the rain like last weekend'),
#  (0,
#   'had bbq chicken pizza last night although wasnt deep dish glad hear you had fun'),
#  (0, 'such chicken'),
#  (0, 'what are you doing here thought you were back work today'),
#  (2,
#   'know want come bec excited but then dont bec its gonna fast then will over'),
#  (1,
#   'ive had that problem too being charmed fast mean ill cross fingers for you'),
#  (0, 'the pics should later today wwwdosriosrestaurantcom'),
#  (1, 'didnt get chat well time eat praline'),
#  (2, 'woah really good the rain earlier was rather nice'),
#  (2,
#   'its blockbuster week new zealand wolverine tomorrow followed star trek thursday'),
#  (2, 'jumping the shower after long day work shall feel ahmazing can math'),
#  (0, 'see you'),
#  (0, 'think have h1n1 maybe just cold'),
#  (1, 'ftw awh sorry probably going the same thing haha'),
#  (0,
#   'want know who that tried ask pkia but still not reply but now change his status away'),
#  (0, 'morning dont ask why early'),
#  (2, 'cool beans yeah man prob all'),
#  (0,
#   'end working gmu short list for masters started sys eng program the 90s never finished'),
#  (0,
#   'instant internet marketing empire bonus recoup your investment hours less'),
#  (1, 'game too bad your leaving'),
#  (2,
#   'just spent the evening gala for her high school drama companys 20th anniversary lots memories'),
#  (0, 'follow lol'),
#  (2,
#   'relaxing bed for while before sleep was nice get out house for while tonight'),
#  (1, 'not yet sorry'),
#  (0, 'playing pet society'),
#  (0, 'just got home from drews bday'),
#  (2, 'good morning hun will promise glad you like have lovely day'),
#  (1,
#   'changed mind dammit tsar can change his mind any time without prior notice'),
#  (0, 'waiting for sumone come online'),
#  (0, 'aniya666 yours wasnt there'),
#  (1, 'hungrybut theres food mah house'),
#  (0, 'sleepover tonight'),
#  (2, 'you cat clean again hope'),
#  (2, 'star wars day may the 4th with you'),
#  (2, 'yum just had mickeyds eggmcmuffin mcyum'),
#  (2, 'just saw zack and miri make with and sooo good'),
#  (0, 'that post was for'),
#  (2, 'wockeez wanna but wont there sure that the show will great'),
#  (2, 'afternoon uve got new pic nice specs'),
#  (0, 'the world beauty and pretty girls testing new version'),
#  (0, 'haha most def rob bank with could get all the swedish fishes the world'),
#  (1, 'sooooooo bored textiles'),
#  (1, 'down again wish could share problems with someone'),
#  (2,
#   'thanks amy that video awesome did you see tmh hes amazing that too bouncy bouncy bouncy'),
#  (1, 'miss your dance friends too'),
#  (0, 'want van basten the milan manager'),
#  (2, 'wow the weather amazing today'),
#  (1,
#   'earlyish night tonight doing overtime work tomorrow again boo for working saturday'),
#  (0, 'tell your grandmother say hello'),
#  (1, 'sad that kids were ungrateful today'),
#  (1, 'bee same here coincidently friend just cancelled our movie date'),
#  (0, 'dios mio weeks left college cant wait'),
#  (2, 'hapee mothers day all the mothers out there'),
#  (1,
#   'braxton was untill 4am and now wont sleep more than minutes time its hard mom days like this'),
#  (2, 'awesome maybe someday ill find book yours the bestsellers list lol'),
#  (2, 'happy meal bob toy'),
#  (0, 'perky purple nail polish isnt perky when its chipped'),
#  (0,
#   'guess you didnt hear the grumbles when kindle came out with cover purse eink screen shortcut broken screen'),
#  (1, 'hollie steel bgt was absolutely excruciating watchpoor girl'),
#  (0, 'after little bit the drink isnt actually strong anymore'),
#  (0, 'green computing'),
#  (1, 'had leave the mrs cuz have work really didnt want'),
#  (2, 'shiv his place slowly hope'),
#  (1,
#   'off get ready for toms gotta make sure hes not done anything stupid ill tweet later'),
#  (0,
#   'character designs complete about week well give another sneak peak stay posted'),
#  (1,
#   'wish could still drink but had two bad nights with white wine london and then was sick for almost week'),
#  (2, 'finally gone the beach yeaaaah'),
#  (2, 'sorry about your sadness nitenite love'),
#  (2,
#   'need them wouldve made picture much cooler mine are bottle green eeyeathooo'),
#  (0, 'wow purple leopard skin fieeerrceee'),
#  (2,
#   'tom saw again guy who looks like you campus today hes sooo adorable but youre still cuter than him haha'),
#  (2, 'jonas second episode aww nick handsome'),
#  (2,
#   'hysterics yaas email writing speech for speakers and doing food technology its good off school monday'),
#  (0,
#   'congrats cuss like that matter minutes but didnt know until now there reward for'),
#  (0, 'has just arrived singapore'),
#  (2,
#   'wish had garden could have bbq tonight might set lounge bbq type thing thatll work fridayfirehazzard'),
#  (2,
#   'houstatlantavegas sooner than later nov 18th night off successful over and over for the last hours heavennn'),
#  (0, 'well actually larin name the model what besides sleeping crawling etc'),
#  (0, 'hoooray hooked already'),
#  (2, 'girl start your day out rightgotta love that'),
#  (2, 'nwilson cmon like the superpower explanation better lol'),
#  (2,
#   'wow tiz almost midnite bedtime for gnite gorgeous ppl hadthebestdayever'),
#  (2, 'thanks homskis its like christmas'),
#  (1, 'only just past 8am and already been spoiled rotton'),
#  (0,
#   'hehe indeed actually nearly changed bio just dont panic but wanted keep the freehugs'),
#  (1, 'sorry definitely getting out this weekend'),
#  (2, 'top gear how love thee'),
#  (0,
#   'yes did see mitch hedberg and the whole floss thing hes hilarious him poor guy'),
#  (2,
#   'assumes wasnt taboo start email with lol considering that the reply got started with rofl pwn3d love the internet'),
#  (0,
#   'great longweekend far going for run now judo tonight then off blue water for some retail therapy'),
#  (2, 'its todays menu dont worry'),
#  (1,
#   'have phone whatchu doing tonight sucka dane cook she sold the tickets lamee'),
#  (0, 'want ghd straightener but the shipping costs pounds deal'),
#  (2,
#   'really enjoyed the podcast with this was 1st time listenening the show will def listen from now'),
#  (1, 'forced myself out bed this morning but failed cycle'),
#  (2, 'crazy fun you make that man nice sri lanka spiritual place yes'),
#  (0,
#   'route home parents 35th wedding anniversary 2day gona take dinner lets find woman can 2getha with that long'),
#  (1, 'apparently have crappy typing skillslol sorry'),
#  (0,
#   'kids class going field trip today and for once was smart enough not volunteer help'),
#  (2,
#   'today jon doe plays the moho excited itï¿½s gonna funny but before have carry all the equipment and the backline'),
#  (2, 'nothing beats spending evening with mom'),
#  (1,
#   'hes back noes have you missed work has been insane and the band has really taken off havent had moment myself'),
#  (0,
#   'haha came home from long night out and all saw tweetie was khayyam wakil usually dont announce and lol'),
#  (0, 'getting installed today'),
#  (0, 'you will never the same'),
#  (0, 'hhhhhhaaaaaaaaaaaaa hve tearsits all fault said cancelled thought'),
#  (0, 'really should put pic guess'),
#  (0, 'please comment back ily'),
#  (0,
#   'hours and many massages later can now spend time with wife and son its mothers day yall dont forget grab gift card'),
#  (2, 'well hopefully the rest the day gets better'),
#  (2,
#   'home last happy mothers all the mothers special thanks father bought tulips did princess adult swim time anime'),
#  (1, 'off class longggg day'),
#  (2,
#   'way didnt know was singing rof thats without doubt fave has done idol thus far eepfangirl moment'),
#  (2, 'had fun early night vegas because pool tomorrow'),
#  (0, 'smiley absolves all'),
#  (2,
#   'saw creditcard statement maybe should receive the unholy aiden fan package yaaaaay'),
#  (0, 'threee words youtube bamboozle show'),
#  (0, 'the way see grandparents'),
#  (1,
#   'the people are coming kill mouse monday have mixed emotions mean lives desk drawer'),
#  (2, 'hey chocolate chips good want snack too but out snacks'),
#  (2, 'happy mothers day hahaha'),
#  (0, 'just talked anthony rapp face face'),
#  (0, 'work til'),
#  (2,
#   'suprised mom with cake and present because its mothers day dad had bought flowers'),
#  (0, 'you can cinderelliiee'),
#  (0, 'totally gonna have money actually buy pair shoes this time'),
#  (2,
#   'repinging pathetic that mom best friend hell know talk mom bout everything everythinggg'),
#  (2,
#   'very nice bea and are bummed cant make should try and get together the near future'),
#  (0, 'omg that did not sound right better grinning thx'),
#  (1,
#   'saw you stalkerishly from the elevator but brookie was eating her moracca had'),
#  (0, 'time for mimis'),
#  (2, 'ooo how love bank holiday'),
#  (1, 'yep tolerate nothing the facebook group'),
#  (2,
#   'going have relaxing hot bath goodnight for now then twits dont worry andy love you more than twitter hehe'),
#  (2, 'what cute dog'),
#  (2, 'you are such positive thinker for sure keeping you around'),
#  (1,
#   'bet its cool down huh its not here havent stopped sweating since noon when dad and were packing'),
#  (2, 'lee lol bugg school thats awsome'),
#  (1,
#   'can just sleep and wake december when house all organized and the baby here feeling like poo today'),
#  (0, 'english class working interactive orals'),
#  (2,
#   'thanks brad looking forward chatting with you too btw like your new pix'),
#  (0, 'girl big hair rock today black velvet baby 5z50g'),
#  (0, 'off pilates now tweet yall soon'),
#  (2,
#   'come all you lovely fans number the local pop charts let launch assault the number slot wwwreverbnationcomsuki'),
#  (2, 'hahaha tempting but nvm quite klutz actually fare better with cam lol'),
#  (0, 'those are the things that mean the world'),
#  (1, 'always forget how much fun kyle'),
#  (2,
#   'the young lady the local chinese taking orders has said very cute indeed pity probably twice her age'),
#  (0, 'this for'),
#  (0, 'glad its friday just got off work and tired'),
#  (2, 'and yes like the vids'),
#  (1, 'god sleepy today can barely focus'),
#  (0, 'and that includes the chotachota stuff released reflexie arcade too'),
#  (0,
#   'walking the puppies downtown also mystery missing cat solved locked himself basement for nearly two days'),
#  (0,
#   'hike the woods with four little kids couldnt that exhausting right wrong lol try downright masochistic'),
#  ...]

# %%
train_iter1 = train_dat
num_class = len(set([label for (label, text) in train_iter1]))
print(num_class)
vocab_size = len(vocab)
emsize = 128
model = TextClassificationModel(vocab_size, emsize, num_class).to(device)
# Out:
# 3

# %% [markdown]
# Let us define our train and evaluate methods

# %%
import time

def train(dataloader):
    model.train()
    total_acc, total_count = 0, 0
    log_interval = 500
    start_time = time.time()

    for idx, (label, text, offsets) in enumerate(dataloader):
        optimizer.zero_grad()
        predited_label = model(text, offsets)
        loss = criterion(predited_label, label)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.1)
        optimizer.step()
        total_acc += (predited_label.argmax(1) == label).sum().item()
        total_count += label.size(0)
        if idx % log_interval == 0 and idx > 0:
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches '
                  '| accuracy {:8.3f}'.format(epoch, idx, len(dataloader),
                                              total_acc/total_count))
            total_acc, total_count = 0, 0
            start_time = time.time()

def evaluate(dataloader):
    model.eval()
    total_acc, total_count = 0, 0

    with torch.no_grad():
        for idx, (label, text, offsets) in enumerate(dataloader):
            predited_label = model(text, offsets)
            loss = criterion(predited_label, label)
            total_acc += (predited_label.argmax(1) == label).sum().item()
            total_count += label.size(0)
    return total_acc/total_count

# %% [markdown]
# Let us create dataloaders for text,train and validation data iterators and then train our model

# %%
from torch.utils.data.dataset import random_split
from torchtext.data.functional import to_map_style_dataset
# Hyperparameters
EPOCHS = 10 # epoch
LR =10  # learning rate
BATCH_SIZE = 16 # batch size for training

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.1)
total_accu = None

train_iter2 = train_dat
test_iter2 =test_dat 
valid_iter2= valid_dat




train_dataloader = DataLoader(train_iter2, batch_size=BATCH_SIZE,
                              shuffle=True, collate_fn=collate_batch)
valid_dataloader = DataLoader(valid_iter2, batch_size=BATCH_SIZE,
                              shuffle=True, collate_fn=collate_batch)
test_dataloader = DataLoader(test_iter2, batch_size=BATCH_SIZE,
                             shuffle=True, collate_fn=collate_batch)

for epoch in range(1, EPOCHS + 1):
    epoch_start_time = time.time()
    train(train_dataloader)
    accu_val = evaluate(valid_dataloader)
    if total_accu is not None and total_accu > accu_val:
      scheduler.step()
    else:
       total_accu = accu_val
    print('-' * 59)
    print('| end of epoch {:3d} | time: {:5.2f}s | '
          'valid accuracy {:8.3f} '.format(epoch,
                                           time.time() - epoch_start_time,
                                           accu_val))
    print('-' * 59)

# %%
train_dataloader

# %%
print('Checking the results of test dataset.')
accu_test = evaluate(test_dataloader)
print('test accuracy {:8.3f}'.format(accu_test))
# Out:
# Checking the results of test dataset.
# test accuracy    0.692

# %% [markdown]
# Test model on text

# %%
sentiment_label = {2:"Positive",
                   1: "Negative",
                   0: "Neutral"
                  }

def predict(text, text_pipeline):
    with torch.no_grad():
        text = torch.tensor(text_pipeline(text))
        output = model(text, torch.tensor([0]))
        return output.argmax(1).item() 
ex_text_str = "soooooo wish i could, but im in school and myspace is completely blocked"
model = model.to("cpu")

print("This is a %s tweet" %sentiment_label[predict(ex_text_str, text_pipeline)])
# Out:
# This is a Neutral tweet
